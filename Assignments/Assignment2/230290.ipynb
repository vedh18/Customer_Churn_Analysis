# %% [markdown]
# # Assignment 2 - DIY LINEAR REGRESSOR!
#
# *This assignment is a part of the project ["Customer Churn Analysis: From Data To Strategy"]*
#
#
# 1.   ## Part-1
# In this part, you'll build your own linear regression from scratch by 2 methods that were discuseed in class.
#
#   * OLS (Ordinary Least Square) - This method directly calculates the values of the coefficients in equation y=mx+c.
#   * Gradient Descent - This method uses an iterative approach to calculate the values of the coefficients. You'll have to calculate the values of both m and b.
# 2.   ## Part-2
# In this part, you'll get predictions from the model you just built. You'll then evaluate the predictions by following metrics:
#
#     * [R2 Score](https://www.investopedia.com/terms/r/r-squared.asp)
#     * [MEAN ABSOLUTE ERROR and ROOT MEAN SQUARED ERROR](https://towardsdatascience.com/what-are-rmse-and-mae-e405ce230383)
# 3.  ## Part-3
# In this part, you'll have to answer some subjective questions.
#
#
#
#
#
#
#
# If you are stuck or have any doubts, please feel free to put your queries on the Whatsapp group.
#
#
# Deadline : **31 May, 11:59 pm**

# %% [markdown]
# # Import necessary libraries
# Feel free to modify it as per your requirements.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part-1

# %% [markdown]
# ### Linear Regressor with OLS method

# %%
class MyLRFromOLS:


  def __init__(self):
      self.m = None
      self.b = None

  def fit(self,X_train,y_train):

    # Calculate values of m and b
    num=0
    den = 0
    for i in range(X_train.shape[0]):

      num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
      den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))

      self.m = num/den
      self.b = y_train.mean() - (self.m * X_train.mean())
    print("m: ",self.m)
    print("b: ",self.b)


  def predict(self,X_test):

    return self.m * X_test + self.b

  def get_coeff(self):
    print(self.m)
    print(self.b)
    # Write code to print the value of m and b

# %%
file_path = '/content/tvmarketing.csv'
df = pd.read_csv(file_path)
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
# Separate input and output columns
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
X
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 199.8, 100.4, 216.4, 182.6,
#        262.7, 198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3,
#        102.7, 131.1,  69. ,  31.5, 139.3, 237.4, 216.8, 199.1, 109.8,
#         26.8, 129.4, 213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4,
#        239.8,  75.3,  68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 109.8,
#        134.3,  28.6, 217.7, 250.9, 107.4, 163.3, 197.6, 184.9, 289.7,
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
#   ### Prediction time

# %%
olslr = MyLRFromOLS()

# %%
olslr.fit(X_train,y_train)
# Out:
# m:  0.052458280858028235
# b:  6.566524608650462

# %%
olslr_pred = olslr.predict(X_test)

# %%
#View predictions
olslr_pred
# Out:
# array([15.78344456, 10.27007924,  9.51467999, 18.7420916 , 15.31656586,
#        16.70146447, 10.03401697, 20.34731499, 10.5061415 , 21.81614685,
#         7.81503169, 17.98669235, 11.68120699,  6.9756992 , 18.23324627,
#         7.46880704,  7.88322746, 14.51395416, 17.56178028, 17.27325973,
#        18.54275013, 20.35780665,  9.58287576,  8.50223517, 18.86799147,
#        15.40049911, 15.75196959, 10.18614599, 18.48504602, 18.31717952,
#        21.08173092, 13.44380523, 17.04768912, 13.71134246,  6.84979933,
#        12.32644385, 18.12308388, 19.59716157, 20.47846069, 16.14540669])

# %%
#Get values of m and b
olslr.get_coeff()
# Out:
# 0.052458280858028235
# 6.566524608650462

# %% [markdown]
# ### Linear Regressor with gradient descent

# %%
class MyLRFromGD:

  def __init__(self,learning_rate,epochs):
    self.m = 10 #assign random value
    self.b  = 10 #assign random value
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X_train,y_train):
      # calcualte b and m using GD
    for i in range(self.epochs):
      y_predicted = self.m * X_train + self.b

      # Calculate slope wrt b and m
      loss_slope_b = (-2 / X_train.size) * (np.sum(y_train - y_predicted))
      loss_slope_m = (-2 / X_train.size) * (np.sum(X_train *(y_train - y_predicted)))

      self.b = self.b - (self.lr * loss_slope_b)
      self.m = self.m - (self.lr * loss_slope_m)


  def predict(self,X_test):
    return self.m * X_test + self.b

  def get_coeff(self):
    print(self.m)
    print(self.b)

# %% [markdown]
# ### Prediction Time
# Since we have already split the dataset, we're not going to repeat it again.

# %%
#Check with different values of learning_rate and epochs for model convergence
gdlr = MyLRFromGD(0.001, 100)

# %%
gdlr.fit(X_train,y_train)

# %%
gdlr_pred = gdlr.predict(X_train)

# %%
# View predictions
gdlr_pred
# Out:
# array([8.88132985e+177, 5.30550141e+177, 7.84297677e+177, 3.99458064e+177,
#        8.28752168e+177, 6.28544714e+177, 5.74355662e+177, 2.28800960e+175,
#        2.38188851e+177, 2.82468367e+176, 4.27363804e+177, 7.21672006e+177,
#        6.96686635e+177, 6.20108095e+177, 2.02170978e+177, 3.56301514e+177,
#        1.02229494e+177, 2.79223514e+176, 6.36157387e+176, 8.98516516e+177,
#        8.07336136e+177, 7.13235387e+177, 3.48513866e+177, 9.52705567e+177,
#        9.22528431e+177, 2.44354072e+177, 8.23560403e+177, 8.11379470e+176,
#        4.25241916e+176, 3.39428277e+177, 5.08160653e+177, 5.80994879e+176,
#        7.79105911e+177, 3.76419605e+177, 1.44412588e+177, 6.29667680e+176,
#        5.58280905e+176, 1.45061559e+177, 5.59753822e+177, 9.28044682e+177,
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Evaluation time
# Let's see how does both of our models perform.

# %%
# Implement R2 Score, MAE and RMSE

class evaluate:

  def __init__(self,y_pred,y_test):
    self.y_pred = y_pred
    self.y_test = y_test

  def r2score(self):
    #Write code here
    ss_total = np.sum((self.y_test - np.mean(self.y_test)) ** 2)
    ss_residual = np.sum((self.y_test - self.y_pred) ** 2)
    r2 = 1 - (ss_residual / ss_total)
    return r2

  def mae(self):
    #Write code here
    mae = np.mean(np.abs(self.y_test - self.y_pred))
    return mae


  def rmse(self):
    #write code here
    rmse = np.sqrt(np.mean((self.y_test - self.y_pred) ** 2))
    return rmse

# %%
# First calculate all the metrics for olslr_pred
evaluator = evaluate(olslr_pred, y_test)

# %%
print("R2 Score:", evaluator.r2score())
# Out:
# R2 Score: 0.042179776427879845

# %%
print("MAE:", evaluator.mae())
# Out:
# MAE: 3.2353682995006396

# %%
print("RMSE:", evaluator.rmse())
# Out:
# RMSE: 4.21816233753514

# %%
print("Shape of y_test:", y_test.shape)
print("Shape of y_pred:", gdlr_pred.shape)

# Ensure the shapes are the same
assert y_test.shape == gdlr_pred.shape
# Out:
# Shape of y_test: (40,)
# Shape of y_pred: (160,)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-71-bcdae277d204> in <cell line: 5>()
#       3
#       4 # Ensure the shapes are the same
# ----> 5 assert y_test.shape == gdlr_pred.shape
#
# AssertionError:

# %%
# Now for gdlr_pred
evaluatorr = evaluate(gdlr_pred, y_test)

# %%
print("R2 Score:", evaluatorr.r2score())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-dab365f77366> in <cell line: 1>()
# ----> 1 print("R2 Score:", evaluatorr.r2score())
#
# <ipython-input-56-53320d469f13> in r2score(self)
#      10     #Write code here
#      11     ss_total = np.sum((self.y_test - np.mean(self.y_test)) ** 2)
# ---> 12     ss_residual = np.sum((self.y_test - self.y_pred) ** 2)
#      13     r2 = 1 - (ss_residual / ss_total)
#      14     return r2
#
# ValueError: operands could not be broadcast together with shapes (40,) (160,)

# %%
print("MAE:", evaluatorr.mae())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-d86c6f066afa> in <cell line: 1>()
# ----> 1 print("MAE:", evaluatorr.mae())
#
# <ipython-input-56-53320d469f13> in mae(self)
#      16   def mae(self):
#      17     #Write code here
# ---> 18     mae = np.mean(np.abs(self.y_test - self.y_pred))
#      19     return mae
#      20
#
# ValueError: operands could not be broadcast together with shapes (40,) (160,)

# %%
print("RMSE:", evaluatorr.rmse())

# %% [markdown]
# # Part-3
# In this part you'll have to answer the questions provided in the below google form:
#
# [Questions](https://forms.gle/2KfpQNvmf5fd9MTw9)
#
# **After Submitting the form, you are required to paste the screenshot of the form.**
#
# ## Steps to add screenshot:
#
#
# 1.   Take the screenshot of the submitted form.
# 2.   Now create a text block below this block in whichever IDE you are using, for example, if you are using VS Code, you will get 2 options below and above each block, Code and Markdown, chose the **Markdown** one.
# 3.   Now insert the image and run the cell.
#
# ### Voila!

# %% [markdown]
# ![Screenshot 2024-05-31 225637.png](data:image/png;base64,...)![Screenshot 2024-05-31 225131.png](data:image/png;base64,...)
